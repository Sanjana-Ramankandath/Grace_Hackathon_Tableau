# %%
import pandas as pd
df = pd.read_csv('mental_health.csv')

# %%
df.Gender.unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'Cis Male', 'Woman', 'f', 'Mal',
#        'Male (CIS)', 'queer/she/they', 'non-binary', 'Femake', 'woman',
#        'Make', 'Genderqueer', 'Female ', 'cis-female/femme',
#        'Guy (-ish) ^_^', 'Male ', 'Man', 'Trans woman', 'msle',
#        'Female (trans)', 'queer', 'Female (cis)', 'Mail', 'cis male',
#        'Malr', 'femail', 'Cis Man'], dtype=object)

# %%
df['Gender'] = df.Gender.replace({'female':'Female'})
df['Gender'] = df.Gender.replace({'Cis Female':'Female'})
df['Gender'] = df.Gender.replace({'F':'Female'})
df['Gender'] = df.Gender.replace({'Woman':'Female'})
df['Gender'] = df.Gender.replace({'Femake':'Female'})
df['Gender'] = df.Gender.replace({'woman':'Female'})
df['Gender'] = df.Gender.replace({'f':'Female'})
df['Gender'] = df.Gender.replace({'Female (cis)':'Female'})
df['Gender'] = df.Gender.replace({'femail':'Female'})
df['Gender'] = df.Gender.replace({'cis-female/femme':'Female'})
df['Gender'] = df.Gender.replace({'Female ':'Female'})

# %%
df['Gender'] = df.Gender.replace({'M':'Male'})
df['Gender'] = df.Gender.replace({'male':'Male'})
df['Gender'] = df.Gender.replace({'m':'Male'})
df['Gender'] = df.Gender.replace({'Male-ish':'Male'})
df['Gender'] = df.Gender.replace({'Cis Male':'Male'})
df['Gender'] = df.Gender.replace({'Mal':'Male'})
df['Gender'] = df.Gender.replace({'Male (CIS)':'Male'})
df['Gender'] = df.Gender.replace({'Man':'Male'})
df['Gender'] = df.Gender.replace({'msle':'Male'})
df['Gender'] = df.Gender.replace({'Make':'Male'})
df['Gender'] = df.Gender.replace({'maile':'Male'})
df['Gender'] = df.Gender.replace({'Male ':'Male'})
df['Gender'] = df.Gender.replace({'Mail':'Male'})
df['Gender'] = df.Gender.replace({'cis male':'Male'})
df['Gender'] = df.Gender.replace({'Malr':'Male'})
df['Gender'] = df.Gender.replace({'Cis Man':'Male'})
df['Gender'] = df.Gender.replace({'Guy (-ish) ^_^':'Male'})
df['Gender'] = df.Gender.replace({'Cis Man':'Male'})

# %%
df['Gender'] = df.Gender.replace({'queer/she/they':'Non-binary'})
df['Gender'] = df.Gender.replace({'Genderqueer':'Non-binary'})
df['Gender'] = df.Gender.replace({'Trans woman':'Non-binary'})
df['Gender'] = df.Gender.replace({'Female (trans)':'Non-binary'})
df['Gender'] = df.Gender.replace({'queer':'Non-binary'})
df['Gender'] = df.Gender.replace({'Trans-female':'Non-binary'})
df['Gender'] = df.Gender.replace({'non-binary':'Non-binary'})

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male', 'Non-binary'], dtype=object)

# %%
df.to_csv("Mental_health_cleaned.csv")

# %%
df.Gender.value_counts()
# Out:
# Male          989
# Female        247
# Non-binary      8
# Name: Gender, dtype: int64

# %%
df
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0      8/27/2014 11:29   37  Female   United States    IL           NaN
# 1      8/27/2014 11:29   44    Male   United States    IN           NaN
# 2      8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 3      8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4      8/27/2014 11:30   31    Male   United States    TX           NaN
# ...                ...  ...     ...             ...   ...           ...
# 1239   9/12/2015 11:17   26    Male  United Kingdom   NaN            No
# 1240    9/26/2015 1:07   32    Male   United States    IL            No
# 1241   11/7/2015 12:36   34    Male   United States    CA            No
# 1242  11/30/2015 21:25   46  Female   United States    NC            No
# 1243    2/1/2016 23:04   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# 0                No       Yes          Often          25-Jun  ...
# 1                No        No         Rarely  More than 1000  ...
# 2                No        No         Rarely          25-Jun  ...
# 3               Yes       Yes          Often          26-100  ...
# 4                No        No          Never         100-500  ...
# ...             ...       ...            ...             ...  ...
# 1239             No       Yes            NaN          26-100  ...
# 1240            Yes       Yes          Often          26-100  ...
# 1241            Yes       Yes      Sometimes  More than 1000  ...
# 1242             No        No            NaN         100-500  ...
# 1243            Yes       Yes      Sometimes          26-100  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# 0          Somewhat easy                        No                      No
# 1             Don't know                     Maybe                      No
# 2     Somewhat difficult                        No                      No
# 3     Somewhat difficult                       Yes                     Yes
# 4             Don't know                        No                      No
# ...                  ...                       ...                     ...
# 1239       Somewhat easy                        No                      No
# 1240  Somewhat difficult                        No                      No
# 1241  Somewhat difficult                       Yes                     Yes
# 1242          Don't know                       Yes                      No
# 1243          Don't know                     Maybe                      No
#
#          coworkers    supervisor mental_health_interview  \
# 0     Some of them           Yes                      No
# 1               No            No                      No
# 2              Yes           Yes                     Yes
# 3     Some of them            No                   Maybe
# 4     Some of them           Yes                     Yes
# ...            ...           ...                     ...
# 1239  Some of them  Some of them                      No
# 1240  Some of them           Yes                      No
# 1241            No            No                      No
# 1242            No            No                      No
# 1243  Some of them            No                      No
#
#      phys_health_interview mental_vs_physical obs_consequence comments
# 0                    Maybe                Yes              No      NaN
# 1                       No         Don't know              No      NaN
# 2                      Yes                 No              No      NaN
# 3                    Maybe                 No             Yes      NaN
# 4                      Yes         Don't know              No      NaN
# ...                    ...                ...             ...      ...
# 1239                    No         Don't know              No      NaN
# 1240                    No                Yes              No      NaN
# 1241                    No                 No              No      NaN
# 1242                    No                 No              No      NaN
# 1243                    No         Don't know              No      NaN
#
# [1244 rows x 27 columns]

# %%
multi_functions = pd.pivot_table(df, index = ['Gender'], values = ['coworkers','supervisor','phys_health_consequence'], aggfunc = [len])
print(multi_functions)
# Out:
#                  len
#            coworkers phys_health_consequence supervisor
# Gender
# Female           247                     247        247
# Male             989                     989        989
# Non-binary         8                       8          8
